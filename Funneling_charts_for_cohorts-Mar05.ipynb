# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import font_manager as fm

# %%
#fpath = "fonts/NotoSans-Regular.ttf"
#font = fm.FontProperties(fname=fpath)

#y = [5,4,3,2,1]
#x = [80,73,58,42,23]
y = [4,3,2,1]
x = [1514,940,505,144]

x_max = 1600
x_min = 0

fig, ax = plt.subplots(1, figsize=(12,6))
for idx, val in enumerate(x):
    left = (x_max - val)/2
    plt.barh(y[idx], x[idx], left = left, color='#d3d3d3', height=1, edgecolor='black')
    # value
    plt.text(800, y[idx], x[idx], ha='center', fontsize=16, color='#2A2A2A')
ax.axis('off')
plt.xlim(x_min, x_max)
# Out:
# (0, 1600)

# %%
#path = '/usr/share/fonts/truetype/msttcorefonts/Comic_Sans_MS.ttf'
#prop = font_manager.FontProperties(fname=path)
#mpl.rcParams['font.family'] = prop.get_name()


# funnel chart
y = [4,3,2,1]
x = [1514,940,505,144]
labels = ['From Abstraction', 'After ADT Use Pipeline', 'After T Test Matching', '~6mons']
x_max = 1600
x_min = 0
x_range = x_max - x_min
#fpath = "fonts/NotoSans-Regular.ttf"
#font = fm.FontProperties(fname=fpath)

fig, ax = plt.subplots(1, figsize=(12,6))
for idx, val in enumerate(x):
    left = (x_range - val)/2
    ax.barh(y[idx], x[idx], left = left, 
             color='#808B96', height=.8)
    # label
    ax.text(800, y[idx]+0.1, labels[idx], ha='center', fontsize=16, color='#2A2A2A')
    # value
    ax.text(800, y[idx]-0.3, str(x[idx])+ " pts", ha='center', fontsize=16, color='#2A2A2A')
    
    if idx != len(x)-1:
        next_left = (x_range - x[idx+1])/2
        shadow_x = [left, next_left, 
                    1600-next_left, 1600-left, left]
        
        shadow_y = [y[idx]-0.4, y[idx+1]+0.4, 
                    y[idx+1]+0.4, y[idx]-0.4, y[idx]-0.4]
        plt.fill(shadow_x, shadow_y, color='grey', alpha=0.6)
        
plt.xlim(x_min, x_max)
plt.axis('off')
plt.title('Abstraction Patient Cohort Patient', loc='center', fontsize=24, color='#2A2A2A')
plt.show()

# %%
#path = '/usr/share/fonts/truetype/msttcorefonts/Comic_Sans_MS.ttf'
#prop = font_manager.FontProperties(fname=path)
#mpl.rcParams['font.family'] = prop.get_name()


# funnel chart
y = [6,5,4,3,2,1]
x = [4391,2450,1783,561,337,118]
labels = ['Total pts from abstraction', 'With at least one ADT dates', 'With an ADT use window', 'With a T baseline', "With T tests after ADT", "With T recovery"]
x_max = 4500
x_min = 0
x_range = x_max - x_min
#fpath = "fonts/NotoSans-Regular.ttf"
#font = fm.FontProperties(fname=fpath)

fig, ax = plt.subplots(1, figsize=(12,6))
for idx, val in enumerate(x):
    left = (x_range - val)/2
    ax.barh(y[idx], x[idx], left = left, 
             color='#808B96', height=.8)
    # label
    ax.text(x[idx]/2+2250, y[idx]+0.1, labels[idx], ha='left', fontsize=16, color='#2A2A2A')
    # value
    ax.text(x[idx]/2+2250, y[idx]-0.3, str(x[idx])+ " pts", ha='left', fontsize=16, color='#2A2A2A')
    
    if idx != len(x)-1:
        next_left = (x_range - x[idx+1])/2
        shadow_x = [left, next_left, 
                    4500-next_left, 4500-left, left]
        
        shadow_y = [y[idx]-0.4, y[idx+1]+0.4, 
                    y[idx+1]+0.4, y[idx]-0.4, y[idx]-0.4]
        plt.fill(shadow_x, shadow_y, color='grey', alpha=0.6)
        
plt.xlim(x_min, x_max)
plt.axis('off')
plt.title('Abstraction Engine Patient Cohort', loc='center', fontsize=20, color='#2A2A2A')
plt.show()
